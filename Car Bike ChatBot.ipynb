# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7be0df0a-1e71-4bd8-98c3-9a892c435b78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7be0df0a-1e71-4bd8-98c3-9a892c435b78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

df = pd.read_csv(io.StringIO(uploaded['CarBikeDataset.csv'].decode('utf-8')))
df
# Out:
#                         Model    Body Type         Performance  \
# 0         Maruti Suzuki Swift    Hatchback  88.5 hp / 180 km/h
# 1               Hyundai Exter  Compact SUV    83 hp / 165 km/h
# 2         Tata Nexon Facelift  Compact SUV   120 hp / 190 km/h
# 3               Mahindra Thar          SUV   150 hp / 155 km/h
# 4         Kia Seltos Facelift          SUV   138 hp / 180 km/h
# 5        Maruti Suzuki Baleno    Hatchback    90 hp / 160 km/h
# 6               Hyundai Creta          SUV   115 hp / 175 km/h
# 7                 Tata Altroz    Hatchback    86 hp / 150 km/h
# 8             Toyota Fortuner          SUV   201 hp / 180 km/h
# 9                 Honda Amaze        Sedan    90 hp / 160 km/h
# 10                 Kia Carens          MPV   115 hp / 160 km/h
# 11            Mahindra XUV700          SUV   200 hp / 200 km/h
# 12      Toyota Innova Hycross          MPV   183 hp / 180 km/h
# 13               Tata Harrier          SUV   168 hp / 180 km/h
# ...

# %%
qa_pairs = []

# %%
data = pd.read_csv('CarBikeDataset.csv')

for index, row in data.iterrows():
    model = row['Model']
    bodytype = row['Body Type']
    performance = row['Performance']
    price = row['Price Range (₹)']
    safety = row['Safety Features']
    engine = row['Engine Type']
    transmission = row['Transmission']
    rating = row['Safety Rating']
    safety = row['Safety Features']
    colors = row['Colors Available']
    economy = row['Fuel Economy Range']

# %%
qa_pairs = []

qa_pairs.append(f"User: What is the price of {model}?")
qa_pairs.append(f"Bot: The price of {model} is approximately {price}.")

qa_pairs.append(f"User: What type of bike is {model} classified as?")
qa_pairs.append(f"Bot: {model} is classified as a {bodytype}.")

qa_pairs.append(f"User: How fast can {model} accelerate from 0-100 km/h?")
qa_pairs.append(f"Bot: {model} can accelerate from 0-100 km/h in about {performance} seconds.")

qa_pairs.append(f"User: What is the engine type used in {model}?")
qa_pairs.append(f"Bot: {model} uses a {engine} engine.")

qa_pairs.append(f"User: What type of transmission does {model} have?")
qa_pairs.append(f"Bot: {model} features a {transmission} transmission system.")

qa_pairs.append(f"User: What is the fuel economy of {model}?")
qa_pairs.append(f"Bot: The fuel economy of {model} is around {economy} km/l.")

qa_pairs.append(f"User: How many colors are available for {model}?")
qa_pairs.append(f"Bot: {model} is available in the following colors: {colors}.")

qa_pairs.append(f"User: What safety features does {model} offer?")
qa_pairs.append(f"Bot: {model} includes safety features such as {safety}.")

qa_pairs.append(f"User: What is the safety rating of {model}?")
qa_pairs.append(f"Bot: {model} has a safety rating of {rating}.")

qa_pairs.append(f"User: How does the acceleration time of {model} compare to other bikes?")
qa_pairs.append(f"Bot: {model} accelerates from 0-100 km/h in {performance} seconds, which is competitive among similar bikes.")

qa_pairs.append(f"User: Which bike has the highest fuel economy?")
qa_pairs.append(f"Bot: Among the current models, {model} boasts the best fuel economy of {economy} km/l.")

qa_pairs.append(f"User: What is the price range of bikes in the dataset?")
qa_pairs.append(f"Bot: The price range for bikes varies from {price}.")

qa_pairs.append(f"User: Is {model} a commuter or a sport bike?")
qa_pairs.append(f"Bot: {model} is categorized as a {bodytype}.")

qa_pairs.append(f"User: What type of rider would benefit most from {model}?")
qa_pairs.append(f"Bot: {model} is ideal for riders who prefer {bodytype} bikes due to its features.")

qa_pairs.append(f"User: What distinguishes {model} from other bikes in its category?")
qa_pairs.append(f"Bot: {model} stands out due to its unique {engine}, {transmission}, and {performance}.")

qa_pairs.append(f"User: How does {model} perform in terms of safety?")
qa_pairs.append(f"Bot: {model} has a safety rating of {rating} and offers safety features like {safety}.")

qa_pairs.append(f"User: What is the most powerful engine available in this dataset?")
qa_pairs.append(f"Bot: The most powerful engine is found in {model}, which has a {engine} engine.")

qa_pairs.append(f"User: Which bike offers the best performance-to-price ratio?")
qa_pairs.append(f"Bot: {model} provides an excellent performance-to-price ratio with a price of {price} and performance of {performance}.")

qa_pairs.append(f"User: What are the common safety features across the bikes in this dataset?")
qa_pairs.append(f"Bot: Common safety features include {safety}.")

qa_pairs.append(f"User: Which model is the best choice for new riders?")
qa_pairs.append(f"Bot: {model} is a great choice for new riders due to its ease of handling and safety features.")

qa_pairs.append(f"User: How does {model} handle in city traffic?")
qa_pairs.append(f"Bot: {model} is designed for urban environments, providing smooth handling.")

qa_pairs.append(f"User: What type of maintenance does {model} require?")
qa_pairs.append(f"Bot: {model} typically requires {engine} maintenance every few months depending on usage.")

qa_pairs.append(f"User: Is {model} suitable for long rides?")
qa_pairs.append(f"Bot: Yes, {model} is suitable for long rides due to its comfortable seat and fuel efficiency of {economy} km/l.")

qa_pairs.append(f"User: How does the fuel efficiency of {model} compare to others?")
qa_pairs.append(f"Bot: {model} offers {economy} km/l, making it highly efficient among bikes of similar engine size.")

qa_pairs.append(f"User: What is the average price of commuter bikes in this dataset?")
qa_pairs.append(f"Bot: The average price of commuter bikes is around {price}.")

qa_pairs.append(f"User: Which bike is the most affordable in this dataset?")
qa_pairs.append(f"Bot: The most affordable bike is {model}, priced at {price}.")

qa_pairs.append(f"User: Can you tell me the engine type of {model}?")
qa_pairs.append(f"Bot: {model} has a {engine} engine, suitable for its {bodytype} design.")

qa_pairs.append(f"User: What is the estimated fuel economy of {model}?")
qa_pairs.append(f"Bot: {model} has a fuel economy range of approximately {economy} km/l.")

qa_pairs.append(f"User: Which transmission does {model} use?")
qa_pairs.append(f"Bot: {model} comes with a {transmission} transmission for optimized performance.")

qa_pairs.append(f"User: How many color options are available for {model}?")
qa_pairs.append(f"Bot: {model} is available in these colors: {colors}.")

qa_pairs.append(f"User: Which bike has the highest safety rating in this dataset?")
qa_pairs.append(f"Bot: The bike with the highest safety rating is {model}, rated at {rating}.")

qa_pairs.append(f"User: What safety rating does {model} hold?")
qa_pairs.append(f"Bot: {model} has a safety rating of {rating}, ensuring a secure ride.")

qa_pairs.append(f"User: What are some standout safety features in {model}?")
qa_pairs.append(f"Bot: {model} includes notable safety features such as {safety}.")

qa_pairs.append(f"User: How much does {model} cost?")
qa_pairs.append(f"Bot: {model} is priced around {price}, making it competitive in its class.")

qa_pairs.append(f"User: Is {model} more suited for city rides or highways?")
qa_pairs.append(f"Bot: {model} is best suited for {bodytype} rides, with design and performance attributes perfect for this purpose.")

qa_pairs.append(f"User: What kind of performance can I expect from {model}?")
qa_pairs.append(f"Bot: {model} offers a performance level of {performance}, ideal for its category.")

qa_pairs.append(f"User: What is the transmission type used in {model}?")
qa_pairs.append(f"Bot: {model} features a {transmission} transmission, enhancing its efficiency and control.")

qa_pairs.append(f"User: How does {model}'s engine impact its fuel economy?")
qa_pairs.append(f"Bot: {model}'s {engine} engine contributes to its fuel economy of around {economy} km/l.")

qa_pairs.append(f"User: Can you list the colors available for {model}?")
qa_pairs.append(f"Bot: {model} is available in a variety of colors, including {colors}.")

qa_pairs.append(f"User: How safe is {model} compared to other bikes?")
qa_pairs.append(f"Bot: {model} has a strong safety rating of {rating} and is equipped with {safety} for optimal safety.")

qa_pairs.append(f"User: What type of engine powers {model}?")
qa_pairs.append(f"Bot: {model} is powered by a {engine} engine, designed to provide reliable performance.")

qa_pairs.append(f"User: Does {model} offer good fuel economy?")
qa_pairs.append(f"Bot: Yes, {model} offers a fuel economy of around {economy} km/l, making it efficient for its class.")

qa_pairs.append(f"User: What are the key features of {model} in terms of safety?")
qa_pairs.append(f"Bot: {model} includes features like {safety} to ensure rider protection.")

qa_pairs.append(f"User: Is {model} available in multiple colors?")
qa_pairs.append(f"Bot: Yes, {model} is offered in several colors, including {colors}.")

qa_pairs.append(f"User: What kind of transmission does {model} come with?")
qa_pairs.append(f"Bot: {model} is equipped with a {transmission} transmission system.")

qa_pairs.append(f"User: How much does it cost to buy {model}?")
qa_pairs.append(f"Bot: {model} is available at a price range of {price}, providing good value.")

qa_pairs.append(f"User: What performance level can I expect from {model}?")
qa_pairs.append(f"Bot: You can expect a performance level of {performance} with {model}, ideal for its {bodytype} type.")

qa_pairs.append(f"User: Does {model} have a good safety rating?")
qa_pairs.append(f"Bot: Yes, {model} has a solid safety rating of {rating}, along with features like {safety}.")

qa_pairs.append(f"User: Which bikes in this dataset have high fuel efficiency?")
qa_pairs.append(f"Bot: Bikes like {model} offer high fuel efficiency with a range of {economy} km/l.")

qa_pairs.append(f"User: Are there bikes with both manual and automatic transmissions?")
qa_pairs.append(f"Bot: Yes, the dataset includes bikes with various transmissions, including {transmission} for {model}.")

qa_pairs.append(f"User: Can you provide a summary of {model} in terms of body type, engine, and safety?")
qa_pairs.append(f"Bot: {model} is a {bodytype} with a {engine} engine, rated {rating} in safety, and equipped with {safety}.")

# %%
with open('qa_pairs.txt', 'w') as f:
  for pair in qa_pairs:
    f.write(pair + '\n')

# %%
# Display the content of qa_pairs.txt
with open('qa_pairs.txt', 'r') as file:
    # Read each line and print
    lines = file.readlines()
    for line in lines[:10]:  # Adjust number to view more or fewer lines
        print(line.strip())

# %%
with open('qa_pairs.txt', 'r') as file:
  data = file.read()

  data = data.replace("\n\n", "\n").strip()

  with open('formatted_qa_pairs.txt', 'w') as f:
    f.write(data)

# %%
# !pip install transformers datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments

# %%
with open('formatted_qa_pairs.txt', 'r') as file:
  lines = file.readlines()

  qa_data = [{"text": line.strip()} for line in lines if line.strip()]

  dataset = Dataset.from_list(qa_data)

# %%
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token

def tokenize_function(examples):
  inputs = tokenizer(examples["text"], padding="max_length", truncation=True)
  inputs["labels"] = inputs["input_ids"].copy()
  return inputs

try:
  tokenized_dataset = dataset.map(tokenize_function, batched=True)
except Exception as e:
  print(f"Error during tokenization: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

# %%
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=1,
    per_device_train_batch_size=1,
    save_steps=500,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 40:43, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=102, training_loss=0.02459394230562098, metrics={'train_runtime': 2489.788, 'train_samples_per_second': 0.041, 'train_steps_per_second': 0.041, 'total_flos': 53303574528000.0, 'train_loss': 0.02459394230562098, 'epoch': 1.0})

# %%
trainer.save_model("fine_tuned_chatbot")

# %%
fine_tuned_model = AutoModelForCausalLM.from_pretrained("fine_tuned_chatbot")

input_text = "User: What is the price of Revolt?\nBot:"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids
output = fine_tuned_model.generate(input_ids, max_length=50)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# User: What is the price of Revolt?
# Bot: Revolt RV400 is priced around 99,999 - 1,20,000.
